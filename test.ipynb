# %%
import pandas as pd

data = pd.read_xml("D:/My_Learning/Non-Coders/data/test-1.xml")
print(pd.DataFrame(data))
# Out:
#      name internal_name units clashtests  selectionsets
# 0  Report        Report     m   \n                  NaN
