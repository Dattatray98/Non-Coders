# %%
import pandas as pd

data = pd.read_csv("D:/My_Learning/Non-Coders/data/kdjlk.csv")
print(pd.DataFrame(data).head())
# Out:
#   clash_name clash_id    status clash_type item1_id      item1_name  \
# 0  Clash-001     C001       New       Hard   P-1001  Pipe Segment 1
# 1  Clash-002     C002    Active       Hard   P-1002  Pipe Segment 2
# 2  Clash-003     C003  Reviewed       Hard   D-2002  Duct Segment B
# 3  Clash-004     C004       New       Hard  CT-3001    Cable Tray 1
# 4  Clash-005     C005    Active       Hard  CT-3002    Cable Tray 2
#
#   item1_type item2_id      item2_name item2_type     x     y     z grid  \
# 0       Pipe   D-2001  Duct Segment A       Duct  3120   540  2400   A1
# 1       Pipe   P-1003  Pipe Segment 3       Pipe  1520   820  2300   B2
# 2       Duct   D-2003  Duct Segment C       Duct  4520  1220  2600   C3
# 3  CableTray   P-1004  Pipe Segment 4       Pipe  2010   610  2200   A2
# 4  CableTray   D-2004  Duct Segment D       Duct  3510   910  2500   B1
#
#      level severity
# 0  Level 2     High
# 1  Level 1     High
# 2  Level 3     High
# 3  Level 2   Medium
# ...
